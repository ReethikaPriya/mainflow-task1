# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing dataset**

# %%
df = pd.read_csv('Megha1_Student-mat.csv')   #import dataset and store that dataset in variable df(dataframe)

# %% [markdown]
# shape of the dataset :means how many rows,columns of the dataset

# %%
df.shape
# Out:
# (395, 33)

# %% [markdown]
# **Display head of the dataset**

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# **display sample dataset** : means it takes all samples of the dataset randomly.

# %%
df.sample(6)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 191     GP   F   17       U     GT3       T     1     1   at_home  services
# 210     GP   F   19       U     GT3       T     3     3     other     other
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 116     GP   M   15       U     GT3       T     4     4     other   teacher
# 336     GP   F   19       R     GT3       A     3     1  services   at_home
# 236     GP   M   17       U     LE3       T     2     2     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 191  ...      5        3      3     1     1      3        0   8   8   9
# 210  ...      4        3      3     1     2      3       10   8   8   8
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 116  ...      4        4      3     1     1      2        2  11  13  14
# 336  ...      5        4      3     1     2      5       12  14  13  13
# ...

# %% [markdown]
# **display dataset datatype**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# **Dataset Selection**

# %% [markdown]
# **use specific columns**

# %%
dfs = pd.read_csv('Megha1_Student-mat.csv',usecols=['G1','G2','G3','sex','studytime',])

# %%
dfs.head()
# Out:
#   sex  studytime  G1  G2  G3
# 0   F          2   5   6   6
# 1   F          2   5   5   6
# 2   F          2   7   8  10
# 3   F          3  15  14  15
# 4   F          2   6  10  10

# %% [markdown]
# **Data  Exploration**

# %%
dfs.sample(5)
# Out:
#     sex  studytime  G1  G2  G3
# 120   F          2  16  15  15
# 215   F          2  14  15  15
# 308   M          2  15  12  12
# 306   M          1  17  18  18
# 281   M          1  11   9  10

# %% [markdown]
# **find missing values**

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
dfs.isnull().sum()
# Out:
# sex          0
# studytime    0
# G1           0
# G2           0
# G3           0
# dtype: int64

# %% [markdown]
# **check this dataset looks mathematically**

# %%
dfs.describe()
# Out:
#         studytime          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     2.035443   10.908861   10.713924   10.415190
# std      0.839240    3.319195    3.761505    4.581443
# min      1.000000    3.000000    0.000000    0.000000
# 25%      1.000000    8.000000    9.000000    8.000000
# 50%      2.000000   11.000000   11.000000   11.000000
# 75%      2.000000   13.000000   13.000000   14.000000
# max      4.000000   19.000000   19.000000   20.000000

# %% [markdown]
# **find duplicate values**

# %%
dfs.duplicated().sum()
# Out:
# 67

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# **if any duplicates use this to drop duplicates**

# %%
dfs.drop_duplicates()
# Out:
#     sex  studytime  G1  G2  G3
# 0     F          2   5   6   6
# 1     F          2   5   5   6
# 2     F          2   7   8  10
# 3     F          3  15  14  15
# 4     F          2   6  10  10
# ..   ..        ...  ..  ..  ..
# 389   F          2   6   5   0
# 391   M          1  14  16  16
# 392   M          1  10   8   7
# 393   M          1  11  12  10
# 394   M          1   8   9   9
#
# [328 rows x 5 columns]

# %% [markdown]
# **check after removing duplicates**

# %%
dfs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Correlation between columns**

# %% [markdown]
# using scipy

# %%
import scipy.stats as stats
import pandas as pd
# Get numeric columns
numeric_cols = dfs.select_dtypes(include=np.number).columns

# Calculate correlation for each pair of numeric columns
correlations = {}
for col1 in numeric_cols:
    correlations[col1] = {}
    for col2 in numeric_cols:
        corr, p_value = stats.pearsonr(dfs[col1], dfs[col2])
        correlations[col1][col2] = corr

# Convert to DataFrame
corr_df = pd.DataFrame(correlations)

# Display the correlation matrix
print(corr_df)
# Out:
#            studytime        G1        G2        G3
# studytime   1.000000  0.144816  0.123780  0.087051
# G1          0.144816  1.000000  0.838025  0.793838
# G2          0.123780  0.838025  1.000000  0.906581
# G3          0.087051  0.793838  0.906581  1.000000

# %% [markdown]
# using numpy

# %%
#here simple code using numpy correlation
dfs.corr(numeric_only=True)
# Out:
#            studytime        G1        G2        G3
# studytime   1.000000  0.144816  0.123780  0.087051
# G1          0.144816  1.000000  0.838025  0.793838
# G2          0.123780  0.838025  1.000000  0.906581
# G3          0.087051  0.793838  0.906581  1.000000

# %% [markdown]
# **Data Analysis**

# %% [markdown]
# **Average Score -G3**

# %% [markdown]
# using numpy

# %%
#here i use numpy
G3_avg = dfs['G3'].mean()
print(G3_avg)
# Out:
# 10.454268292682928

# %% [markdown]
# using scipy

# %%
import scipy.stats as stats
G3_data = dfs['G3'].to_numpy()  # Extract 'G3' column as NumPy array
G3_stats = stats.describe(G3_data)  # Get descriptive statistics
G3_avg = G3_stats.mean  # Access the mean value
print(G3_avg)
# Out:
# 10.454268292682928

# %% [markdown]
# **Find above 15 in their final grade**

# %% [markdown]
# using numpy

# %%
#here i use numpy
G3_above_15 = dfs[dfs['G3'] > 15]
print(G3_above_15)
# Out:
#     sex  studytime  G1  G2  G3
# 8     M          2  16  18  19
# 14    M          3  14  16  16
# 22    M          2  15  15  16
# 31    M          2  17  16  17
# 32    M          2  17  16  16
# 36    M          3  15  16  18
# 42    M          2  19  18  18
# 47    M          4  19  19  20
# 59    F          2  15  16  16
# 69    F          4  16  16  16
# 91    F          1  16  17  18
# 101   M          3  16  17  17
# 104   M          2  16  18  18
# 107   M          3  16  18  18
# 109   F          3  14  15  16
# 110   M          1  18  19  19
# 129   M          1  18  18  18
# 167   F          2  14  15  16
# 171   M          2  13  15  16
# 182   F          2  16  17  17
# 196   M          1  17  15  16
# 198   F          1  18  18  18
# 200   F          2  16  16  16
# 222   F          2  16  16  17
# 260   F          2  17  18  18
# 265   M          2  17  17  17
# 286   F          3  18  18  19
# 293   F          4  18  18  18
# 299   M          1  16  15  16
# ...

# %% [markdown]
# using scipy

# %%
import scipy.stats as stats
import numpy as np
G3_data = dfs['G3'].to_numpy()  # Extract 'G3' column as NumPy array

# Apply the condition using NumPy's boolean indexing
filtered_indices = np.where(G3_data > 15)

# Get the filtered rows from the DataFrame
G3_above_15 = dfs.iloc[filtered_indices]

print(G3_above_15)
# Out:
#     sex  studytime  G1  G2  G3
# 8     M          2  16  18  19
# 14    M          3  14  16  16
# 22    M          2  15  15  16
# 31    M          2  17  16  17
# 32    M          2  17  16  16
# 36    M          3  15  16  18
# 42    M          2  19  18  18
# 47    M          4  19  19  20
# 59    F          2  15  16  16
# 69    F          4  16  16  16
# 91    F          1  16  17  18
# 101   M          3  16  17  17
# 104   M          2  16  18  18
# 107   M          3  16  18  18
# 109   F          3  14  15  16
# 110   M          1  18  19  19
# 129   M          1  18  18  18
# 167   F          2  14  15  16
# 171   M          2  13  15  16
# 182   F          2  16  17  17
# 196   M          1  17  15  16
# 198   F          1  18  18  18
# 200   F          2  16  16  16
# 222   F          2  16  16  17
# 260   F          2  17  18  18
# 265   M          2  17  17  17
# 286   F          3  18  18  19
# 293   F          4  18  18  18
# 299   M          1  16  15  16
# ...

# %% [markdown]
# **Correlation between study time and final grade (G3)**

# %% [markdown]
# correlation using numpy

# %%
corr_st_G3=dfs['studytime'].corr(dfs['G3'])
print(corr_st_G3)
# Out:
# 0.08705111475400322

# %% [markdown]
# correlation using scipy

# %%
import scipy.stats as stats
studytime_data = dfs['studytime'].to_numpy()
G3_data = dfs['G3'].to_numpy()
corr_st_G3, p_value = stats.pearsonr(studytime_data, G3_data)
print(corr_st_G3)
# Out:
# 0.08705111475400311

# %% [markdown]
# **Which gender has a higher average final grade (G3)**

# %%
male_avg_G3 = dfs[dfs['sex'] == 'M']['G3'].mean() #calculate avg G3 for males
female_avg_G3 = dfs[dfs['sex'] == 'F']['G3'].mean() #calculate avg G3 for females
print("Average G3 for males:", male_avg_G3) #print avg male G3
print("Average G3 for females:", female_avg_G3) # print avg female G3
# Out:
# Average G3 for males: 11.075949367088608
# Average G3 for females: 9.876470588235295

# %%
#calculate which gender has highest average final grade(G3)
if male_avg_G3 > female_avg_G3:
    print("Males have a higher average G3 than females.")
else:
    print("Females have a higher average G3 than males.")
# Out:
# Males have a higher average G3 than females.

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# **plot Histogram of final grade (G3)**

# %%
# here i use matplotlib for histogram
plt.hist(dfs['G3'],bins=10,edgecolor='black')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Frequency')
plt.title('Histogram of Final Grade (G3)')
plt.show()

# %%
#here i increase bins.Bins means range of values on the graph,mainly used in histogram
plt.hist(dfs['G3'],bins=50,edgecolor='black')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Frequency')
plt.title('Histogram of Final Grade (G3)')
plt.show()

# %%
#here i use seaborn for histogram and also i use KDE -(Kernel Density Estimate)
# KDE -it provides a smooth,continuous curve representing the distrubution of data
# Kde parameter is set to true to enable the kde along with distplot.
sns.histplot(dfs['G3'],bins=10,kde=True)
plt.xlabel('Final Grade (G3)')
plt.ylabel('Frequency')
plt.title('Histogram of Final Grade (G3)')
plt.show()

# %%
# here kde set to false
sns.histplot(dfs['G3'],bins=10,kde=False)
plt.xlabel('Final Grade (G3)')
plt.ylabel('Frequency')
plt.title('Histogram of Final Grade (G3)')
plt.show()

# %% [markdown]
# **Scatter plot between the studytime and final grade(G3)**

# %%
#here i use matplotlib for scatter plot
plt.scatter(dfs['studytime'],dfs['G3'])
plt.xlabel('Study Time')
plt.ylabel('Final Grade (G3)')
plt.title('Scatter Plot of Study Time vs Final Grade (G3)')
plt.show()

# %%
#here i use seaborn for scatterplot
sns.scatterplot(data=dfs,x='studytime',y='G3')
plt.xlabel('Study Time')
plt.ylabel('Final Grade (G3)')
plt.title('Scatter Plot of Study Time vs Final Grade (G3)')
plt.show()

# %% [markdown]
# By seeing this graph we can say that the data is non-linear so the points do not form straight line.
# for non-linear dataset suitable algorithms are:
# 1.polynomial regression
# 2.decision tree regression
# 3.Random forest regression

# %% [markdown]
# **Create a bar chart comparing the average scores of male and female students.**

# %% [markdown]
# using numpy

# %%
#here code for average scores of gender in all final grades (G1,G2,G3) .
import matplotlib.pyplot as plt
import numpy as np

# Calculate average scores for G1, G2, and G3 for male and female students
grades = ['G1', 'G2', 'G3']
male_avg_scores = [dfs[dfs['sex'] == 'M'][grade].mean() for grade in grades]
female_avg_scores = [dfs[dfs['sex'] == 'F'][grade].mean() for grade in grades]

# Create bar plot
fig, ax = plt.subplots()
bar_width = 0.35
opacity = 0.8
index = np.arange(len(grades))

# Create bars for male and female scores
rects1 = ax.bar(index, male_avg_scores, bar_width,
                alpha=opacity, color='b',
                label='Male')
rects2 = ax.bar(index + bar_width, female_avg_scores, bar_width,
                alpha=opacity, color='y',
                label='Female')

# Set labels and title
ax.set_xlabel('Grade')
ax.set_ylabel('Average Score')
ax.set_title('Average Scores by Gender and Grade')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(grades)
ax.legend()

# Display plot
plt.show()

# %% [markdown]
# using scipy

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
# Calculate average scores for G1, G2, and G3 for male and female students
grades = ['G1', 'G2', 'G3']
male_avg_scores = [dfs[dfs['sex'] == 'M'][grade].mean() for grade in grades]
female_avg_scores = [dfs[dfs['sex'] == 'F'][grade].mean() for grade in grades]

# Create bar plot
fig, ax = plt.subplots()
bar_width = 0.35
opacity = 0.8
index = np.arange(len(grades))
# Create bars for male and female scores
rects1 = ax.bar(index, male_avg_scores, bar_width,
                alpha=opacity, color='b',
                label='Male')
rects2 = ax.bar(index + bar_width, female_avg_scores, bar_width,
                alpha=opacity, color='y',
                label='Female')
# Set labels and title
ax.set_xlabel('Grade')
ax.set_ylabel('Average Score')
ax.set_title('Average Scores by Gender and Grade')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(grades)
ax.legend()

# Display plot
plt.show()

# %%
#here the code for average scores of gender in final grade(G3)
import matplotlib.pyplot as plt
import numpy as np

# Calculate the average G3 score for male and female students
male_avg_G3 = dfs[dfs['sex'] == 'M']['G3'].mean()
female_avg_G3 = dfs[dfs['sex'] == 'F']['G3'].mean()

# Create a bar plot
fig, ax = plt.subplots()
bar_width = 0.35
opacity = 0.8 #used for transparency of visual element like filled area

# Define the x-axis positions for the bars
index = np.arange(2)

# Create the bars
rects1 = ax.bar(index, [male_avg_G3, female_avg_G3], bar_width,
                alpha=opacity, color=['blue', 'pink'],
                label=['Male', 'Female'])

# Set the labels and title
ax.set_xlabel('Gender')
ax.set_ylabel('Average G3 Score')
ax.set_title('Average Scores of Male and Female Students')

# Set the x-axis tick labels
ax.set_xticks(index)
ax.set_xticklabels(['Male', 'Female'])

# Add a legend
ax.legend()

# Display the plot
plt.show()
